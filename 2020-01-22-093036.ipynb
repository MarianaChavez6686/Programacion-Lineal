# %%
2+2
# Out:
# 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-200,200,100)

# %%
y=np.cos(x)

# %%
plt.plot(x,y)
plt.show()

# %%
y=np.sin(x)*np.exp(-0.1*x)

# %%
plt.plot(x,y)
plt.show()
